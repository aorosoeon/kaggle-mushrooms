# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# !kaggle --version
# Out:
# Kaggle API 1.6.17

# %%
# !kaggle competitions download -c playground-series-s4e8
# Out:
# ...
# 100%|██████████████████████████████████████| 82.3M/82.3M [00:40<00:00, 2.24MB/s]
# 100%|██████████████████████████████████████| 82.3M/82.3M [00:40<00:00, 2.13MB/s]

# %%
# !unzip playground-series-s4e8.zip
# Out:
# Archive:  playground-series-s4e8.zip
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
# !rm playground-series-s4e8.zip

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import sklearn
import tqdm
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')
df
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 0              0     e          8.80         f           s         u
# 1              1     p          4.51         x           h         o
# 2              2     e          6.94         f           s         b
# 3              3     e          3.88         f           y         g
# 4              4     e          5.85         x           l         w
# ...          ...   ...           ...       ...         ...       ...
# 3116940  3116940     e          9.29         f         NaN         n
# 3116941  3116941     e         10.88         s         NaN         w
# 3116942  3116942     p          7.82         x           e         e
# 3116943  3116943     e          9.45         p           i         n
# 3116944  3116944     p          3.20         x           s         g
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  ...  \
# ...

# %%
df_test_data = pd.read_csv('test.csv')
df_test_data
# Out:
#               id  cap-diameter cap-shape cap-surface cap-color  \
# 0        3116945          8.64         x         NaN         n
# 1        3116946          6.90         o           t         o
# 2        3116947          2.00         b           g         n
# 3        3116948          3.47         x           t         n
# 4        3116949          6.17         x           h         y
# ...          ...           ...       ...         ...       ...
# 2077959  5194904          0.88         x           g         w
# 2077960  5194905          3.12         x           s         w
# 2077961  5194906          5.73         x           e         e
# 2077962  5194907          5.03         b           g         n
# 2077963  5194908         15.51         f         NaN         w
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# 0                          t             NaN          NaN          w
# ...

# %%
df_sample_submission = pd.read_csv('sample_submission.csv')
df_sample_submission
# Out:
#               id class
# 0        3116945     e
# 1        3116946     e
# 2        3116947     e
# 3        3116948     e
# 4        3116949     e
# ...          ...   ...
# 2077959  5194904     e
# 2077960  5194905     e
# 2077961  5194906     e
# 2077962  5194907     e
# 2077963  5194908     e
#
# [2077964 rows x 2 columns]

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3116945 entries, 0 to 3116944
# Data columns (total 22 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    3116945 non-null  int64
#  1   class                 3116945 non-null  object
#  2   cap-diameter          3116941 non-null  float64
#  3   cap-shape             3116905 non-null  object
#  4   cap-surface           2445922 non-null  object
#  5   cap-color             3116933 non-null  object
#  6   does-bruise-or-bleed  3116937 non-null  object
#  7   gill-attachment       2593009 non-null  object
#  8   gill-spacing          1858510 non-null  object
#  9   gill-color            3116888 non-null  object
#  10  stem-height           3116945 non-null  float64
#  11  stem-width            3116945 non-null  float64
#  12  stem-root             359922 non-null   object
#  13  stem-surface          1136084 non-null  object
# ...

# %%
df_test_data.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2077964 entries, 0 to 2077963
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    2077964 non-null  int64
#  1   cap-diameter          2077957 non-null  float64
#  2   cap-shape             2077933 non-null  object
#  3   cap-surface           1631060 non-null  object
#  4   cap-color             2077951 non-null  object
#  5   does-bruise-or-bleed  2077954 non-null  object
#  6   gill-attachment       1728143 non-null  object
#  7   gill-spacing          1238369 non-null  object
#  8   gill-color            2077915 non-null  object
#  9   stem-height           2077963 non-null  float64
#  10  stem-width            2077964 non-null  float64
#  11  stem-root             239952 non-null   object
#  12  stem-surface          756476 non-null   object
#  13  stem-color            2077943 non-null  object
# ...

# %%
df_sample_submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2077964 entries, 0 to 2077963
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   id      int64
#  1   class   object
# dtypes: int64(1), object(1)
# memory usage: 31.7+ MB

# %%
df.describe(include='all')
# Out:
#                   id    class  cap-diameter cap-shape cap-surface cap-color  \
# count   3.116945e+06  3116945  3.116941e+06   3116905     2445922   3116933
# unique           NaN        2           NaN        74          83        78
# top              NaN        p           NaN         x           t         n
# freq             NaN  1705396           NaN   1436026      460777   1359542
# mean    1.558472e+06      NaN  6.309848e+00       NaN         NaN       NaN
# std     8.997847e+05      NaN  4.657931e+00       NaN         NaN       NaN
# min     0.000000e+00      NaN  3.000000e-02       NaN         NaN       NaN
# 25%     7.792360e+05      NaN  3.320000e+00       NaN         NaN       NaN
# 50%     1.558472e+06      NaN  5.750000e+00       NaN         NaN       NaN
# 75%     2.337708e+06      NaN  8.240000e+00       NaN         NaN       NaN
# max     3.116944e+06      NaN  8.067000e+01       NaN         NaN       NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# id                            0
# class                         0
# cap-diameter                  4
# cap-shape                    40
# cap-surface              671023
# cap-color                    12
# does-bruise-or-bleed          8
# gill-attachment          523936
# gill-spacing            1258435
# gill-color                   57
# stem-height                   0
# stem-width                    0
# stem-root               2757023
# stem-surface            1980861
# stem-color                   38
# veil-type               2957493
# veil-color              2740947
# has-ring                     24
# ring-type                128880
# spore-print-color       2849682
# habitat                      45
# season                        0
# dtype: int64

# %% [markdown]
# # Steps
# 1. Read https://archive.ics.uci.edu/dataset/73/mushroom
#
# 2. Read https://www.kaggle.com/competitions/playground-series-s4e8/overview
# 3. Plot distributions through pd and plt commands
# 4. Import profiler, check its report
# 5. Try preprocess data for Sequential() and use the model
# 6. Fine-tune it, so you have 98% on validation
# 7. Try XGBoost, random forest, extra-trees classifier, and more complex NNs
